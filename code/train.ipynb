# %%
from game import Game
from agent import Agent
import training_functions as tf

# %%
version = 'version_3'
# env, agent, eps = tf.load_state(version)

env = Game(size=4, 
           seed=42, 
           negative_reward=-2, 
           reward_mode='log2', 
           tile_move_penalty=0.1)
eps = 0.5
# Create the agent, duplicating default values for visibility
agent = Agent(state_size=env.state_size * 18, 
              action_size=env.action_size,
              seed=42, 
              fc1_units=2048, 
              fc2_units=1024, 
              fc3_units = 128,
              buffer_size = 1000000, 
              batch_size = 1024, 
              lr = 0.005, 
              use_expected_rewards=True, 
              predict_steps = 2, 
              gamma = 0.5)

# %%
tf.dqn(agent=agent, 
       version=version, 
       env=env,
       n_episodes=200000,
       eps_start=eps or 0.05,
       eps_end=0.00001,
       eps_decay=0.999,
       sample_mode='random',
       start_learn_iterations=10)
# Out:
# 4039/200000 | 0.28s | Score:288 | Average Score:410 | Total Rewards:208 | Average Total Rewards:271 | Max Tile Reached:512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tf.dqn(agent=agent,
#       2        version=version,
#       3        env=env,
#       4        n_episodes=200000,
#       5        eps_start=eps or 0.05,
#       6        eps_end=0.00001,
#       7        eps_decay=0.999,
#       8        sample_mode='random',
#       9        start_learn_iterations=10)
#
# File c:\Users\rjmee\2048_DRL\code\training_functions.py:140, in dqn(agent, version, env, n_episodes, eps_start, eps_end, eps_decay, sample_mode, start_learn_iterations)
#     137         if done:
#     138             break
# --> 140 agent.learn(learn_iterations, mode=sample_mode, save_loss=True, weight=env.game_board.max())
#     142 actions = actions /env.steps
#     144 agent.actions_deque[0].append(actions[0])
#
# File c:\Users\rjmee\2048_DRL\code\agent.py:223, in Agent.learn(self, learn_iterations, mode, save_loss, gamma, weight, bootstrapping)
#     219     learn_iterations = self.learn_iterations
#     221 for i in range(learn_iterations):
# --> 223     states, actions, rewards, next_states, done = self.memory.sample(mode=mode)
#     225     Q_expected = self.qnetwork_local(states).gather(1, actions)
#     227     loss = F.mse_loss(Q_expected, rewards)
#
# File c:\Users\rjmee\2048_DRL\code\replay_buffer.py:156, in ReplayBuffer.sample(self, mode)
#     153     for i in list(t.itertuples(name='Experience', index=False)):
#     154         experiences.append(i)
# --> 156 states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
#     157 actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
#     158 rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
#
# File c:\Users\rjmee\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:
